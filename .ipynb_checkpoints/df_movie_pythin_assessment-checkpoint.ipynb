# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dplus = pd.read_csv('data/disney_plus.csv', index_col = 0)

# %%
dplus
# Out:
#             type                           title                    director  \
# show_id
# s1         Movie                   A Spark Story  Jason Sterman, Leanne Dare
# s2         Movie                  Spooky Buddies                Robert Vince
# s3         Movie          The Fault in Our Stars                  Josh Boone
# s4       TV Show                 Dog: Impossible                         NaN
# s5       TV Show  Spidey And His Amazing Friends                         NaN
# ...          ...                             ...                         ...
# s1364      Movie          The Sword in the Stone         Wolfgang Reitherman
# s1365      Movie                 Those Calloways                Norman Tokar
# s1366    TV Show            Disney Kirby Buckets                         NaN
# s1367    TV Show                  Disney Mech-X4                         NaN
# s1368    TV Show              Imagination Movers                         NaN
#
#                                                       cast  \
# show_id
# s1                           Apthon Corbin, Louis Gonzales
# s2       Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...
# s3       Shailene Woodley, Ansel Elgort, Laura Dern, Sa...
# s4                                            Matt Beisner
# s5       Benjamin Valic, Lily Sanfelippo, Jakari Fraser...
# ...                                                    ...
# s1364    Sebastian Cabot, Karl Swenson, Rickie Sorensen...
# s1365    Brian Keith, Vera Miles, Brandon de Wilde, Wal...
# s1366    Jacob Bertrand, Mekai Curtis, Cade Sutton, Oli...
# s1367    Nathaniel Potvin, Raymond Cham, Kamran Lucas, ...
# s1368    Rich Collins, Dave Poche, Scott Durbin, Scott ...
#
#                        country          date_added  release_year rating  \
# show_id
# s1                         NaN  September 24, 2021          2021  TV-PG
# s2       United States, Canada  September 24, 2021          2011      G
# s3               United States  September 24, 2021          2014  PG-13
# s4               United States  September 22, 2021          2019  TV-PG
# s5               United States  September 22, 2021          2021   TV-Y
# ...                        ...                 ...           ...    ...
# s1364            United States     October 1, 2019          1963      G
# s1365            United States     October 1, 2019          1965     PG
# s1366            United States                 NaN          2014  TV-Y7
# s1367                   Canada                 NaN          2016  TV-Y7
# s1368            United States                 NaN          2008   TV-Y
#
#           duration                                  listed_in  \
# show_id
# s1          88 min                                Documentary
# s2          93 min                      Comedy, Fantasy, Kids
# s3         127 min              Coming of Age, Drama, Romance
# s4       2 Seasons       Animals & Nature, Docuseries, Family
# s5        1 Season          Action-Adventure, Animation, Kids
# ...            ...                                        ...
# s1364       80 min        Action-Adventure, Animation, Comedy
# s1365      132 min            Animals & Nature, Drama, Family
# s1366    3 Seasons    Action-Adventure, Comedy, Coming of Age
# s1367    2 Seasons  Action-Adventure, Comedy, Science Fiction
# s1368    3 Seasons                                Kids, Music
#
#                                                description
# show_id
# s1       Two Pixar filmmakers strive to bring their uni...
# s2       The puppies go on a spooky adventure through a...
# s3       Hazel and Gus share a love that sweeps them on...
# s4       Matt Beisner uses unique approaches to modifyi...
# s5       Spidey teams up with pals to become The Spidey...
# ...                                                    ...
# s1364    Merlin trains a young orphan who's destined to...
# s1365    A strong-willed family struggles to establish ...
# s1366     Welcome to Kirby's world! It's rude and sketchy.
# s1367    Ryan discovers his ability to control a giant ...
# s1368    Rock out with the Imagination Movers, Disney J...
#
# [1368 rows x 11 columns]

# %%
print(dplus.dtypes)
# Out:
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ## 1
# Create a dataframe titled `movie_ratings` that contains the ratings (G, PG, TV-G, etc) and how many of those movies exist in the dataframe.

# %%
movie_ratings = dplus['rating'].value_counts()

# %%
movie_ratings
# Out:
# rating
# TV-G        307
# TV-PG       275
# G           235
# PG          227
# TV-Y7       130
# TV-14        72
# PG-13        60
# TV-Y         48
# TV-Y7-FV     12
# Name: count, dtype: int64

# %% [markdown]
# ## 2
# Using the `movie_ratings` dataframe, create a **bar chart** that displays the count of the top 5 movie ratings.
# > 💡 *Hint: Use `.plot.bar()` with `x='rating'` and `y='count'`. Don't forget to add a title and axis label!*

# %%
movie_ratings.nlargest(5).plot.bar()

plt.xlabel('Rating')
plt.ylabel('Count')
plt.title('Top 5 Movie Ratings')
# Out:
# Text(0.5, 1.0, 'Top 5 Movie Ratings')

# %% [markdown]
# ## 3
# Using `movies_df`, subset the data to create a new dataframe named **`year_duration`** that contains only two columns:
# - `release_year`
# - `duration`

# %%
year_duration = dplus[['release_year', 'duration']]

# %%
year_duration
# Out:
#          release_year   duration
# show_id
# s1               2021     88 min
# s2               2011     93 min
# s3               2014    127 min
# s4               2019  2 Seasons
# s5               2021   1 Season
# ...               ...        ...
# s1364            1963     80 min
# s1365            1965    132 min
# s1366            2014  3 Seasons
# s1367            2016  2 Seasons
# s1368            2008  3 Seasons
#
# [1368 rows x 2 columns]

# %% [markdown]
# ## 4
# Using your `year_duration` dataframe, filter for movies released between **1975 and 1984** (inclusive) and find the:
# - **Minimum** duration
# - **Maximum** duration
# - **Average** duration

# %%
dur_time = year_duration[~year_duration['duration'].astype(str).str.contains('Season', na=False)]

# %%
dur_time
# Out:
#          release_year duration
# show_id
# s1               2021   88 min
# s2               2011   93 min
# s3               2014  127 min
# s7               2009  106 min
# s8               2021   22 min
# ...               ...      ...
# s1360            2001   73 min
# s1362            1978  104 min
# s1363            1986   75 min
# s1364            1963   80 min
# s1365            1965  132 min
#
# [991 rows x 2 columns]

# %%
dur_time['duration'] = dur_time['duration'].str[:-4].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 dur_time['duration'] = dur_time['duration'].str[:-4].astype('int')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
year_duration.loc[(year_duration.release_year >= 1975) & (year_duration.release_year <= 1984)].describe()
# Out:
#        release_year
# count     38.000000
# mean    1979.000000
# std        2.818855
# min     1975.000000
# 25%     1977.000000
# 50%     1979.000000
# 75%     1981.000000
# max     1984.000000

# %% [markdown]
# ## 5
# Using the `year_duration` dataframe, create a **scatterplot** that shows movie durations over the years. Add a descriptive title to your chart.
# After creating your plot, answer the following in a comment or markdown cell:
# > *Do you notice any correlation between release year and movie duration?*

# %%
plt.scatter(year_duration.release_year, year_duration.duration)
plt.xlabel("Release Year")
plt.ylabel("Duration")
plt.title("Movie Durations over Time")
# Out:
# Text(0.5, 1.0, 'Movie Durations over Time')

# %% [markdown]
# ## 6
# Find the **actual correlation value** between `release_year` and `duration`.
# > 💡 *Hint: Use `.corr()` on the `year_duration` dataframe.*
# Answer the following in a comment or markdown cell:
# > *Based on the correlation value, is there a meaningful correlation between release year and duration?*

# %% [markdown]
# ## 7
# Using `movies_df`, find which **year had the most G-rated movie releases**.
# > 🎯 *Challenge: Can you accomplish this in a single line of code?*

# %%
g_rated_movies = dplus[dplus['rating'] == 'G']

year_counts = g_rated_movies.groupby('release_year').size()

best_year = year_counts.idxmax()
max_releases = year_counts.max()

print(f"The year with the most G-rated movie releases is {best_year} with {max_releases} releases.")
# Out:
# The year with the most G-rated movie releases is 2003 with 12 releases.

# %% [markdown]
# ## 8
# 1. Find which **year had the most total movie releases**.
# 2. Create a new dataframe containing only movies from that year.
# 3. Convert the `duration` column to integers.
# 4. Use the **IQR method** to determine the upper and lower cutoffs for outliers.
# 5. Calculate what **percentage of movies** from that year had durations that were statistical outliers.
# > 💡 *Hint: Outlier cutoffs are defined as:*
# > - *Lower cutoff: Q1 − (1.5 × IQR)*
# > - *Upper cutoff: Q3 + (1.5 × IQR)*

# %%
top_year = dplus['release_year'].value_counts().idxmax()

# %%
print(top_year)
# Out:
# 2020

# %%
top_year_movies = dplus[dplus['release_year'] == 2020].copy()

# %%
top_year_movies
# Out:
#             type                                              title  \
# show_id
# s11        Movie                                  Jade Eyed Leopard
# s22      TV Show                              Mira, Royal Detective
# s37      TV Show                   Life Below Zero: Next Generation
# s55      TV Show  Walt Disney Animation Studios: Short Circuit E...
# s59      TV Show                       Critter Fixers: Country Vets
# ...          ...                                                ...
# s557       Movie                                          Lamp Life
# s559     TV Show                        Diary of a Future President
# s568       Movie            Forky Asks a Question: What is Reading?
# s569       Movie                                               Loop
# s572       Movie             Forky Asks a Question: What is Cheese?
#
#                  director                                               cast  \
# show_id
# s11                   NaN                                       Jeremy Irons
# s22                   NaN  Leela Ladnier, Utkarsh Ambudkar, Roshni Edward...
# s37                   NaN                                      Mocean Melvin
# s55                   NaN                                                NaN
# s59                   NaN                                     Sullivan Jones
# ...                   ...                                                ...
# s557     Valerie LaPointe     Annie Potts, Jim Hanks, Ally Maki, Emily Davis
# s559                  NaN  Tess Romero, Selenis Leyva, Charlie Bushnell, ...
# s568         Bob Peterson  Tony Hale, Addison Andrews, Mila Crespo, Imani...
# s569         Erica Milsom  Madison Bandy, Christiano Delgado, Louis Gonza...
# s572         Bob Peterson               Tony Hale, Jeff Garlin, Bob Peterson
#
#                country          date_added  release_year rating   duration  \
# show_id
# s11                NaN  September 17, 2021          2020  TV-PG     44 min
# s22      United States   September 8, 2021          2020   TV-Y  2 Seasons
# s37      United States     August 25, 2021          2020  TV-14  2 Seasons
# s55                NaN      August 4, 2021          2020     PG  2 Seasons
# s59      United States       July 28, 2021          2020  TV-14  2 Seasons
# ...                ...                 ...           ...    ...        ...
# s557     United States    January 31, 2020          2020   TV-G     11 min
# s559     United States    January 17, 2020          2020  TV-PG  2 Seasons
# s568     United States    January 10, 2020          2020   TV-G      7 min
# s569     United States    January 10, 2020          2020     PG     12 min
# s572     United States     January 3, 2020          2020   TV-G      6 min
#
#                                               listed_in  \
# show_id
# s11                       Animals & Nature, Documentary
# s22                            Animation, Fantasy, Kids
# s37      Action-Adventure, Animals & Nature, Docuseries
# s55                        Animation, Anthology, Family
# s59                Animals & Nature, Docuseries, Family
# ...                                                 ...
# s557                          Animation, Comedy, Family
# s559                      Comedy, Coming of Age, Family
# s568                          Animation, Comedy, Family
# s569                                  Animation, Family
# s572                          Animation, Comedy, Family
#
#                                                description
# show_id
# s11      Jade Eyed Leopard follows a leopard, Toto, thr...
# s22      Mira is the new royal detective in the land of...
# s37      The next generation of Alaskans struggle to su...
# s55      Welcome to Short Circuit - an experimental sho...
# s59      Dr. Hodges and Dr. Ferguson own and operate a ...
# ...                                                    ...
# s557     Lamp Life answers the question of what happene...
# s559     Elena Cañero-Reed will one day become the U.S....
# s568     The energetic Peas-n-a-Pod siblings teach Fork...
# s569     Adrift on a lake, two kids with different ways...
# s572     Buttercup, annoyed with all of Forky’s questio...
#
# [109 rows x 11 columns]

# %%
top_year_movies['duration'] = top_year_movies['duration'].str.extract('(/d+)').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 top_year_movies['duration'] = top_year_movies['duration'].str.extract('(/d+)').astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: cannot convert float NaN to integer

# %% [markdown]
# ## 9
# Add a new column called **`length_category`** to `movies_df` that categorizes each movie as one of the following:
#
# | Category  | Duration               |
# |-----------|------------------------|
# | `short`   | 30 minutes or less     |
# | `average` | Between 31–120 minutes |
# | `long`    | More than 120 minutes  |
#
# **Bonus:** Once the column is created, create a **pie chart** showing the distribution of movie length categories.

# %%
dplus['length_category'] = [

# %% [markdown]
# ## 10
# 1. Create a new column called **`gap`** that calculates the difference between the year a movie was added to Disney+ and its original `release_year`.
# 2. Find the **movie with the greatest gap**.
# 3. Find the **average gap** across all movies.
